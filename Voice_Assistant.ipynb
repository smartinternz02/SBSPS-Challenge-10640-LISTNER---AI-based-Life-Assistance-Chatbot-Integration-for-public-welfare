# %%
import pyttsx3
import speech_recognition as sr
import webbrowser
import datetime
import pyjokes
import os
import time
def sptext():      # Speech to text
    recognizer=sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
        try:
            print("recognizing...")
            data = recognizer.recognize_google(audio)
            print(data)
            return data
        except sr.UnknownValueError:
            print("Not Understanding")
sptext()
  
def speechtx(x):     # text to speech
    engine = pyttsx3.init()
    voices = engine.getProperty('voices')
    engine.setProperty('voice',voices[0].id) # for selecting single voice
    rate = engine.getProperty('rate')
    engine.setProperty('rate',150) #volume set 
    engine.say(x)
    engine.runAndWait()

if __name__ == '__main__':
    if "hey jarvis" in sptext().lower():
        while True:  
                data1=sptext().lower()
                if "your name" in data1:
                    name = " my name is javis"
                    speechtx(name)



                elif "old are you" in data1:
                    age="i am two years old"
                    speechtx(age)
                elif 'time' in data1:
                    time = datetime.datetime.now().strftime("%I%M%p")
                    speechtx(time)
                elif 'youtube' in data1:
                    webbrowser.open("https://www.youtube.com/")
                elif 'web' in data1:
                    webbrowser.open("https://shivalikcollege.edu.in")
                elif 'flipkart' in data1:
                    webbrowser.open("https://flipkart.com")
                elif 'amazon' in data1:
                    webbrowser.open("https://amazon.com") 
                elif 'joke' in data1:
                    joke_1 = pyjokes.get_joke(language="en",category="neutral")
                    speechtx(joke_1)
                elif 'play song' in data1:
                    add = "C:\music"
                    listsong = os.listdir(add)
                    print(listsong)
                    os.startfile(os.path.join(add,listsong[1]))

                elif "exit" in data1:
                    speechtx("thank you")
                    break
                time.sleep(10)
                #else:
                #    print("thanks")
# Out:
# Listening...
# recognizing...
# result2:
# {   'alternative': [   {'confidence': 0.92995489, 'transcript': 'hello Jarvis'},
#                        {'transcript': 'hello Javis'},
#                        {'transcript': 'chalo Jarvis'},
#                        {'transcript': 'hello Javes'},
#                        {'transcript': 'hallo Jarvis'}],
#     'final': True}
# hello Jarvis
# Listening...
# recognizing...
# result2:
# {   'alternative': [   {'confidence': 0.90274262, 'transcript': 'play song'},
#                        {'transcript': 'play a song'},
#                        {'transcript': 'place song'},
#                        {'transcript': 'play the song'},
#                        {'transcript': 'Le song'}],
#     'final': True}
# play song
